# %% [markdown]
# # Dynamics of Mass, Space and Time in Vector Calculus
#
# By Arend Lammertink, MScEE. E-mail: lamare at gmail dot com.
#
#
# **Very preliminary draft version**
#
# For questions and/or discussion, you can go to [ResearchGate](https://bit.ly/ScientificBreakthrough21).
#
# The theory described in this article has been completely rewritten and published as a preprint:
#
# [Space Time Potential Theory: A Fundamental Second-Order Approach](http://dx.doi.org/10.13140/RG.2.2.34596.28801).
#
# ----
#
#
# ## Abstract
#
# It is shown that from the assumption that all space is filled with a superfluid
# medium called aether, characterized by the quantum circulation constant $k$, a
# fully integrated, **unified second order model** of mass, space and time can be
# derived.
#
# Within the superfluid model we are describing here, it is shown that an
# alternative unit of measurement can be derived for the Coulomb, which is
# subsequently defined as one kilogram per second [kg/s], allowing an actual
# physical description of the nature of charge within a model that has only three
# fundamental units of measurement: the meter [m], the second [s] and the kilogram
# [kg]. This in contrast to the rather phenomenological description we have today
# in the form of Maxwell's equations.
#
# Furthermore, it is shown that a second order spatial wave equation can be
# derived, of which the sultions are consistent with those found in quantum
# mechanics, but without the need for probabilistic interpretations and valid on
# any scale, from the quantum to the cosmological, so the nuclear forces are
# no longer needed to describe the dynamics of the atom.
#
# Finally, it is shown that the gravitational force can also be described along
# Richard Feyman's description of the Biefeld-Brown effect.
#
# And thus we have come to a **unified "theory of everything"** that is next level on "cutting the crap".
#
# Or, to quote Steve Jobs:
# <p style="text-align: center;">"Simplicity is the ultimate sophistication."</p>

# %% [markdown]
# ## Introduction
#
#
# After the negative result in the famous Michelson–Morley experiment, the at that
# time prevalent aether theory was abandoned in favor of Einstein's relativity
# theory. This experiment was based upon the idea that the gravitational force was
# a force that propagated independently from the electromagnetic forces and it was
# assumed the aether was stationary and thus it was assumed that the movements of
# planetary bodies through the aether would result in disturbances of the aether,
# which would influence the speed of light and that should be detectable. When
# that turned out not to be the case, it unfortunately was the aether theory that
# was abandoned, while the incorrect assumption that the gravitational force is a
# force that is independent from the electromagnetic forces is still the prevalent
# view today.
#
# To make matters worse, it turns out that Maxwell made the mistake of entangling
# the circuit level Faraday law with the fundamental medium model, which resulted
# in wave equations that were not invariant to the good old Galilean coordinate
# transform. And it is this mistake that eventually led to the Lorentz transform,
# which is what eventually led to special relativity. In the words of C.K.
# Thornhill:
#
# (Ref: [Real or Imaginary Space-Time? Reality or Relativity?](https://etherphysics.net/CKT4.pdf) )
#
# "*It was the mistaken idea, that Maxwell’s equations and the standard wave
# equation should be invariant, which led, by a mathematical freak, to the Lorentz
# transform (which demands the non-ether concept and a universally constant
# wave-speed) and to special relativity.*"
#
# And since special relativity is the currently accepted theory of gravity, it is
# now widely accepted its predictions do not agree with various astrophysical
# observations:
#
# (Ref: [Wikipedia - Dark Matter](https://en.wikipedia.org/wiki/Dark_matter) )
#
# "*Various astrophysical observations – including gravitational effects [...]
# cannot be explained by currently accepted theories of gravity.*"
#
# Despite of these results, rather than considering the relativity theory to be
# disproven and abandoning it, it was concluded that no less than 85% of the mass
# in the Universe was unaccounted for and was called "Dark Matter":
#
# "*In the standard Lambda-CDM model of cosmology, the total mass-energy content
# of the universe contains 5% ordinary matter, 26.8% dark matter, and 68.2% of a
# form of energy known as dark energy. Thus, dark matter constitutes 85% of the
# total mass, while dark energy and dark matter constitute 95% of the total
# mass-energy content.*"
#
# This conundrum is rather naturally resolved when we describe the aether as a
# superfluid medium that has a certain mass density $\rho$ as well as a certain
# charge density $\rho_{q0}$, thus abandoning the idea that the vacuum of outer
# space is empty yet magically able to support the propagation of a/o
# electromagnetic waves.
#
# However, while obviously special relativity is unable to predict gravitational
# effects on a cosmic scale correctly by a large margin, it does correctly predict
# the existence of length contraction as well as clock slowing, which is expressed
# by the Lorentz factor:
#
# (Ref: [Wikipedia - Lorentz factor](https://en.wikipedia.org/wiki/Lorentz_factor) )
#
# $$
# \displaystyle \gamma = \frac{1}{\sqrt{1 - \frac{v^2}{c^2} } }.
# $$
#
# <p style="text-align: right;">(eq. 1)</p>
#
# So, the question before us is not the fact that length contraction as well as
# clock slowing are real effects that are a/o responsible for the fact that one
# will always measure the same speed of light anywhere in the Universe in a local
# experiment.
#
# The question before us is whether that constant speed of light we are measuring
# implies that the speed of light is constant across the entire Universe, implying
# on it's turn that time itself is relative via the Lorentz transform, or that
# there is only an **apparent** constant speed of light, because length
# contraction and clock slowing cancel one another out in any local measurement.
#
# This brings us to the work of Ron Hatch, who held like 12 patents on the GPS
# technology and was one of the most outspoken critics of the relativity theory
# because of his work on the actual GPS system:
#
# (Ref: [Youtube - Relativity in the Light of GPS Talk 2016](http://www.youtube.com/watch?v=VOQweA_J4S4) )
#
# In this speech, he addresses many issues around relativity and the lessons that
# can be learned from GPS. He proposes an aether theory as an alternative, his
# modified Lorentz ether theory (MLET), which apparently still considers the
# aether as being stationary:
#
# (Ref: [Clock Behavior and the Search for an Underlying Mechanism for Relativistic Phenomena](http://www.tuks.nl/pdf/Reference_Material/Ronald_Hatch/Hatch-Clock_Behavior_and_theSearch_for_an_Underlying_Mechanism_for_Relativistic_Phenomena_2002.pdf) )
#
# "*The [Lorentz] scale factor, $\gamma$, used in SRT with relative velocities is defined in MLET using **absolute velocities**.*"
#
# In this paper, he also addresses many issues, including the Sagnac effect, and
# draws some extraordinary conclusions like this one:
#
# "*The requirement that the sun’s gravitational potential not be applied to
# clocks resident on or moving in the earth’s inertial frame gives very strong
# support to the MLET theory. But, even more significant, it **clearly invalidates
# the Einstein theories**.*"
#
# So, if the 85% error margin in the prediction of gravitational effects on a
# cosmic scale isn't already enough of an invalidation, we can add this issue to
# conclude that it should not have been the aether theory that was abandoned, but
# rather that it is Einsteinian relativity that should be abandoned.
#
# The bottomline, however, is that aether theories can predict the (local) results
# of the relativity just as well, without requiring time itself to be relative nor
# the speed of light to be absolutely constant across the entire Universe:
#
# "*In an interesting study, Mansouri and Sexl show that in most respects a
# Lorentz absolute ether theory with length contraction and clock slowing is
# equivalent to SRT. [...] Thus, SRT has it backwards. It assumes the apparent
# equivalence of inertial frames is real and uses that result, together with the
# magic of a universal speed of light, to derive length contraction and clock
# slowing. On the other hand, the ether theories use the length contraction and
# clock slowing to show that there is an **apparent** equivalence of all inertial
# frames and an **apparent** common universal speed of light.*"
#
# This brings us to the fundamental relation between space and time in our
# Universe. In the relativity theory, this fundamental relation is expressed in
# the form of the Lorentz coordinate transform, which elevates the, as we now know
# **apparent**, common universal speed of light into an absolute Universal
# constant that defines a fundamental relation between space and time in such a
# manner that absolutely nothing can propagate faster than the speed of light in
# vacuum, even including information.
#
# However, various anomalies have been reported of the observation of anomalous
# superlumincal signals, a/o with optical fibres and microwaves. There are 20
# references about this in our earlier work in which a/o the discovery of the
# fundamental relation between space and time in our Universe is described
# (equation 36) and eventually led to the theory of everything we are presenting
# here.
#
# (Ref: [Revision of Maxwell's equations](https://bit.ly/RevisionOfMaxwellsEquations) )
#
# The most notable of these references are these two papers by [Dr. Steffen
# Kühn](https://www.researchgate.net/profile/Steffen-Kuehn-3), because he has done
# both the math:
#
# (Ref: [General Analytic Solution of the Telegrapher’s Equations and the Resulting Consequences for Electrically Short Transmission Lines](https://www.researchgate.net/publication/342150114) )
#
# "*Based on classical circuit theory, this article develops a general analytic
# solution of the telegrapher’s equations, in which the length of the cable is
# explicitly contained as a freely adjustable parameter. For this reason, the
# solution is also applicable to electrically short cables. Such a model has
# become indispensable because a few months ago, it was experimentally shown that
# voltage fluctuations in ordinary but electrically short copper lines move at
# signal velocities that are significantly higher than the speed of light in a
# vacuum. This finding **contradicts the statements of the special theory of
# relativity but not, as is shown here, the fundamental principles of electrical
# engineering**.*"
#
# As well as the experiment, where he demonstrated that a time shift between two
# demodulated audiosignals from the one and the same broadcast station can be
# detected with his plasma antenna, thus confirming the possibility of
# superluminal signal transmission through the medium:
#
# (Ref: [Experimental detection of superluminal far-field radio waves with transverse plasma antennas](https://www.researchgate.net/publication/361736479) )
#
# "*[I]n a specifically designed experimental setup of two mutually stationary and
# very distant antennas, electromagnetic waves may travel at **velocities that
# exceed the speed of light in vacuum**. This effect, previously predicted only
# theoretically, has now been experimentally investigated and **confirmed**. This
# finding indicates that **Lorentz-Einstein electrodynamics is incorrect** and
# that Maxwell's equations should instead be interpreted in terms of Weber
# electrodynamics.*"
#
# At this point, it should be clear that the Einstein-Lorentz paradigm is
# untenable and that the transmission and reception of superluminal signals is
# entirely possible, which forces us to reevaluate our fundamental equations and
# assumptions around the Nature of space and time, as Einstein talked about
# decades ago:
#
# "*You believe in the God who plays dice, and I in complete law and order in a
# world which objectively exists, and which I, in a wildly speculative way, am
# trying to capture. I hope that someone will discover a more **realistic** way,
# or rather **a more tangible basis** than it has been my lot to find. Even the
# great initial success of the Quantum Theory does not make me believe in the
# fundamental dice-game, although I am well aware that our younger colleagues
# interpret this as a consequence of senility. No doubt the day will come when we
# will see whose instinctive attitude was the correct one.*" (Albert Einstein to
# Max Born, Sept 1944, 'The Born-Einstein Letters')
#
# And while the day that quantum magicians realize that fundamental randomness
# implies one can have an action without a cause and become aetherists has not yet
# come, according to this paper by Michael Clover just the assumption of
# simultaneous measurements alone already invalidates "all proofs of Bell's
# theorem", the method by which "spooky action at a distance" is supposedly
# proven, while "only time-independent classical local hidden variable theories
# are forbidden by violations of the original Bell inequalities".
#
# (Ref: [Article Bell's Theorem: A Critique](https://www.researchgate.net/publication/2194718_Bell's_Theorem_A_Critique) )
#
# But let's continue with Einstein:
#
# "*All my attempts to adapt the theoretical foundation of physics to this new
# type of knowledge (Quantum Theory) failed completely. It was as if the ground
# had been pulled out from under one, with **no firm foundation to be seen
# anywhere, upon which one could have built**.*" (P. A Schlipp, Albert Einstein:
# Philosopher – Scientist, On Quantum Theory, 1949)
#
# This has now changed, because with the discovery of the quantum circulation
# constant $k$, which has a value equal to $c^2$ but a unit of measurement in
# $[m^2/s]$, it has now become possible to formulate such a realistic, tangible
# and fundamental foundation for our new physics. And this is possible because it
# turns out we can combine this quantum circulation constant $k$ with the vector
# Laplacian to define the **time derivative of any given vector field in physical
# three dimensional space-time** as follows:
#
# $$
# \displaystyle \frac{d \vec F}{dt} = - k \Delta \vec F.
# $$
# <p style="text-align: right;">(eq. 2)</p>
#
# Obviously, the units of measurements match: $[/s] = [m^2/s] [/m^2]$.
#
# This is very significant, because it enables us to define higher order Laplace
# and Poisson equations in three dimensions and it also gives us the opportunity
# to obtain a much deeper understanding of the Nature of space and time in our
# Universe.
#
# In other words: **this is the fundamental equation that will one day be
# recognized as one of the biggest scientific breakthroughs of the 21st century**,
# because there is simply no argument to be made against such a simple and
# straightforward application of the vector Laplacian.
#
# With the new foundation, we can describe a "firm foundation" consisting of a
# number of fields that describe the dynamics of the superfluid medium itself.
# This answers many questions and highlights the error(s) in Maxwell's equations,
# but that does not in and of itself explain what particles are or what charge is.

# %% [markdown]
# ## Methods
#
# It is possible to describe the dynamics of a superfluid medium using the
# fundamental relationship between space and time we found to compute the time
# derivative of the velocity field $v$, acceleration $a$. This results in a
# Helmholtz decomposition whereby we obtain two acceleration fields representing
# the linear and angular components. By multiplying the linear component with the
# mass density $\rho$ we obtain a field similar to the familiar $\vec E$ field
# that has a unit of measurement of force density, while multiplying vorticity
# $\omega$ by viscosity $\eta$ we obtain an angular field similar to the familiar
# $\vec B$ field, that has a unit of measurement of torque density.
#
# We can also compute the time derivatives thereof to define two second order
# fields, whereby the linear component has a unit of measurement of yank density,
# the time derivative of force density, and the angular component desctibes the
# time derivative of torque density which doesn't have a name yet.
#
# Obviously, this way we can describe higher order time derivatives in three
# dimensions, which was heretofore impossible.
#
# The advantage of this method is that the resulting potential fields are uniquely
# defined, leaving no room for "gauge fixing". Also, because the resulting fields
# are obtained by simply writing out the definition of the vector Laplacian and
# multiplying by a few constants, we are sure the fields thus defined are 100%
# mathematically correct and consistent and free of singularities as well.
#
# Another advantage of this method is that there are only three units of
# measurement, the meter $[m]$, the second $[s]$ and the kilogram $[kg]$, which
# allows for the straightforward description of the dynamics of the superfluid
# medium and the integration of the electromagnetic domain with the domain of
# fluid dynamics, provided we are able to relate the units of measurement used in
# the electromagnetic domain to those used in the superfluid model, but also
# provided we are able reproduce equations like Coulomb's law and the Lorentz
# force in a satisfactory manner.
#
# The final advantige of this method is that a second order spatial wave operator
# and equation can be derived that have no explicit time dependence ($d/dt$),
# while the solutions of this wave equation are consistent with the solutions
# found in quantum mechanics but without the need for probabilistic
# interpretations while valid on any scale, from the quantum to the cosmological.

# %% [markdown]
# ### Definition of the medium
#
# We assume all space to be filled with a superfluid like medium, which behavior can be defined by three constants: the speed of licht, the viscosity of the medium and Planck's constant.
#
# Hereby, we define the value of viscosity $\eta$ by the inverse of vacuum permeability  $\mu_0$, which used to be defined as:  $4\pi \times 10^{-7}$ H/m.
#
# (Ref: [Wikipedia](https://en.wikipedia.org/wiki/Vacuum_permeability) )
#
#
# ----

# %%
from math import *

c     = 299792458.0     # speed of light     [m/s]
eta   = 1/(4*pi*1e-7)   # viscosity          [kg/m-s],   [Pa-s] 
h     = 6.62607015e-34  # Planck's constant  [kg-m^2/s], [J-s]

# %% [markdown]
# From here, we can define further constants, starting with mass density $\rho$, which we initially define to have a value equal to permittivity ${\epsilon_0}$, but a unit of measurement in $[kg/m^3]$ by using the definition of permittivity ${\epsilon_0}$:
#
# $$
# \displaystyle {\epsilon_0 = \frac{1}{c^2 \mu_0}}.
# $$
# <p style="text-align: right;">(eq. 3)</p>
#
# And substituting $\rho = \epsilon_0$ and $\eta = 1/\mu_0$:
#
# $$
# \displaystyle {\rho = \frac{\eta}{c^2}}.
# $$
# <p style="text-align: right;">(eq. 4)</p>
#
# This comes within 10 significant digits of the SI value for permittivity ${\epsilon_0}$, also known as the electric constant. The reason for this is that the susceptibility ${\mu_0}$ has been redefined in 2019, while we prefer the classical exact definition.
#
# From here, we can work out the unit of measurement for charge in Coulomb by equating the units of measurement of $\rho$ in $[\frac{kg}{m^3}]$ and $\epsilon_0$  in $[\frac{C^2}{N-m^2}]$ or $[\frac{C^2 \cdot s^2}{kg \cdot m^3}]$:
#
# $$
# \frac{C^2 \cdot s^2}{kg \cdot m^3} = \frac{kg}{m^3} \Rightarrow C^2 \cdot s^2 = kg^2 \Rightarrow C = \frac{kg}{s}
# $$
# <p style="text-align: right;">(eq. 5)</p>
#
# Thus, charge in Coulombs can be viewed as having the unit $[\frac{kg}{s}]$, providing a new physical dimension to the concept of charge.
#
#
# Then, we can define the diffusivity, kinematic viscosity or quantum circulation constant $k$, as follows:
#
# $$
# \displaystyle k = \frac{\eta}{\rho}.
# $$
# <p style="text-align: right;">(eq. 6)</p>
#
# This way, we obtain a unit of measurement in $[m^2/s]$ and a value equal to light speed c squared for $k$.
#
# However, because $c$ currently has an exact definition, we change the order of these definitions a bit and define $k$ as having a value equal to $c^2$ and a unit of measurement in $[m^2/s]$ and use that to define mass density $\rho$ as follows:
#
# $$
# \displaystyle \rho  = \frac{\eta}{k}.
# $$
#
# <p style="text-align: right;">(eq. 7)</p>
#
# Fundamentally, neither light speed $c$, quantum circulation $k$ nor mass density $\rho$ can be considered absolute Universal constants, as argued by a/o Hatch. But it appears that viscosity $\eta$ may be an actual Universal constant, given it's classical exact definition that includes $\pi$, suggesting it actually represents some kind of geometric proportion.
#
# ----

# %%
k   = c**2  # quantum circulation constant
            # 8.987551787368176e+16                 [m^2/s]
rho = eta/k # mass density   8.85418781762039e-12   [kg/m^3]    

print("c   = ", c)
print("eta = ", eta)
print("rho = ", rho)
print("k   = ", k)
# Out:
# c   =  299792458.0
# eta =  795774.7154594767
# rho =  8.85418781762039e-12
# k   =  8.987551787368176e+16

# %% [markdown]
# ### Elementary charge e
#
# Next, we define the value of elementary charge exactly as defined in the SI system, but assign a unit of measurement in kilogram per second [kg/s] as explained above:
#
# (Ref: [Wikipedia](https://en.wikipedia.org/wiki/Elementary_charge) )

# %%
e     = 1.602176634e-19 # elementary charge  [kg/s]

# %% [markdown]
# ### Elementary mass m
#
# Next, we define elementary mass, which is quite unusual. This originates at the quantized vortices observed in rotating superfluids, with a circulation equal to $κ_o = h/m$, so if the circulation is given by the quantum circulation constant $k$, we can compute elementary mass by: $m = h/k$:
#
# (Ref. [Vortices in rotating superfluid He](https://www.pnas.org/doi/10.1073/pnas.96.14.7760) )
#
# "Around one vortex line $κ$ equals the circulation quantum, $κ_o = h/m$."
#
# This computes to about 7.372e-51 kg and a rather interesting detail is that when we compute the Compton frequency for a particle with that mass, we obtain 1 Hertz $[Hz]$, while the accompanying wavelength computes to the value of c, but then of course in meters $[m]$.
#
# In the following, it is assumed an elementary particle exists that can be characterized by a/o this mass $m$.

# %%
m     = h/k        # elementary mass 7.372497323812708e-51 [kg]
fc    = (m*c**2/h) # Compton frequency
lc    = h/(m*c)    # Compton wavelength

print("m    =", m)
print("fc   =", fc)
print("c/lc =", c/lc)
# Out:
# m    = 7.372497323812708e-51
# fc   = 1.0
# c/lc = 1.0000000000000002

# %% [markdown]
# ### Vacuum charge density $\rho_{q0}$
#
# When we consider the unit for charge density within our new framework, $[\frac{\text{kg}}{\text{m}^3 \cdot \text{s}}]$,  **charge density** represents a **mass flux density** in our model. Thus, we can define (linear) charge density as the divergence of momentum density:
#
# $$
# \rho_q = \nabla \cdot (\rho \vec v).
# $$
# <p style="text-align: right;">(eq. 8)</p>
#
# An interesting observation within our model is that the charge to mass ratio of
# a particle results in a unit of measurement in per second or Hertz [Hz],
# yielding a characteristic oscillation frequency for such a particle. For the
# electron, this frequency computes to approximately 175.88 GHz, which falls
# within 10% of the calculated spectral radiance dEν/dν in the observed cosmic
# background radiation which peaks at 160.23 GHz and is calculated from a measured
# CMB temperature of approximately 2.725 K, suggesting a possible connection.
#
# This suggestion leads to the idea that even though we can describe the aether
# itself as a superfluid, we cannot consider even the vacuum in outer space as
# devoid from any particles, disturbances or (zero point) energy and thus we can
# consider it to have a certain charge density $\rho_{q0}$, a background charge
# density, which can be considered to be the charge density of the vacuum.
#
# We can define this vacuum charge density $\rho_{q0}$ by:
#
# $$
# \rho_{q0} = q \frac{\rho}{m} = q \frac{\eta}{h} = q \frac{\rho k}{h} = q \frac{ \eta}{m k}
# $$
# <p style="text-align: right;">(eq. 9)</p>
#
# with $q$ = elementary charge $e$. This results in a unit of measurement in $[\frac{\text{kg}}{\text{m}^3 \cdot \text{s}}]$, representing a charge density in our model.

# %%
rho_q0 = (e/m) * rho       # Vacuum charge density 1.9241747011042014e+20   [kg/m^3-s]

print("rho_q0 = ", rho_q0)
# Out:
# rho_q0 =  1.924174701104201e+20

# %% [markdown]
# ### Vector Laplacian
#
# The vector Laplacian plays a crucial role in our model and is defined by:
#
# $$
# \displaystyle \Delta \vec F = \text{grad div} \vec F - \text{curl curl} \vec F.
# $$
#
# <p style="text-align: right;">(eq. 10)</p>
#
# (Ref. [Wikipedia](https://en.wikipedia.org/wiki/Laplace_operator#Vector_Laplacian) )
#
# The vector Laplace operator describes the second spatial derivative in three dimensions, which would be the three dimensional generalization of the one dimensional $d^2/dx^2$, and has a unit of measurement in per meter squared $[/m^2]$.
#
# What the Laplace operator does is establish a Helmholtz decomposition of the vector field $\vec F$, whereby the term grad div $\vec F$ results in a **linear** component, the curl free or irrotational field usually denoted $\vec E$, and the term curl curl $\vec F$ results in an **angular** component, the divergence free or incompressible field usually denoted $\vec B$. And these two components may be evaluated independently of one another.
#
# (Ref. [Wikipedia](https://en.wikipedia.org/wiki/Helmholtz_decomposition) )
#
# It is because of this resulting Helmholtz decomposition that the vector Laplacian actually defines a fundamental symmetry between these linear and angular components and it is that fundamental symmetry that is broken in theories that do not derive their fields directly using the vector Laplacian, which includes Maxwell's equations as well as Navier-Stokes.
#
# The div operator in the vector Laplacian is defined as a surface integral over a
# spherical volume $(4/3) \pi R^3$, divided by radius R, whereby the limit of R is
# taken to zero, while the grad operator returns the change in a scalar field $f$
# over a displacement dR, divided by the distance dR.
#
# Similarly, the curl operator also has a unit in [$/m$] and is defined as a
# line integral over a closed curve, divided by the area enclosed by that curve,
# whereby the limit of the area is taken to zero.
#
# It is important to note that the div operator involves an integral over the
# surface of a volume, and therefore works on a **volume** rather than a surface, while
# the curl operator involves a line integral over a closed curve, and therefore
# works on a **surface** rather than a volume.
#
# The difference between these volumetric and planar operations is crucial in the
# understanding of the geometric aspects of the vector Laplacian, which becomes
# clear when implementing a fdtd simulator using a staggered Yee grid. In our work
# on a simulator, we found that it is necessary to implement two distinct
# versions of the curl operator and that there is a fundamental difference between
# volumetric "point" fields and "surface" fields.
#
# (Ref. [Operators.py](https://github.com/l4m4re/fdtd/blob/master/fdtd/operators.py ))
#
# In other words, the discrete finite difference implementation of the vector
# Laplacian learns that the various fields in the model are located at specific
# geometric points in space relative to one another, a detail that is lost in
# infinitesimal calculus.

# %% [markdown]
# ### Field Definitions
#
# In the following, we will define the fields in our model, whereby we use the symbol $\Gamma$ for the circulation in line with fluid dynamics. For the aether this circulation $\Gamma$ is equal to the quantum circulation constant $k$.
#
# We can define both scalar and vector potentials by working out the vector Laplacian for the velocity field, multiplied by the circulation constant, to compute the acceleration field:
#
# $$\vec{a} = - \Gamma \Delta \vec{v}$$
# <p style="text-align: right;">(eq. 11)</p>
#
# Which, considering the definition of the vector Laplacian $\Delta$, works out to:
#
# $$
# \vec{a} = \Gamma \left( -\nabla \nabla \cdot \vec{v}
#         + \nabla \times \nabla \times \vec{v} \right),
# $$
# <p style="text-align: right;">(eq. 12)</p>
#
# We can now define fields similar to the familiar scalar potential $\Phi$, vector
# potential $\vec A$ and the familiar $\vec E$ and $\vec B$ fields.
#
# However, in order to maintain consistency, we deviate from the traditional
# definition for the vector potential, both in electrodynamics as well as fluid
# dynamics, where the fluid dynamics vector potential $\vec A_{fd}$ is defined by:
#
# $$
# \Delta\vec A_{fd} = - \nabla \times ( \nabla \times \vec A_{fd} ) = - \vec \omega .
# $$
# <p style="text-align: right;">(eq. 13)</p>
#
# (Ref. Richardson, S., & Cornish, A. (1977). Solution of three-dimensional
# incompressible flow problems. Journal of Fluid Mechanics, 82(2), 309-319.
# [doi:10.1017/S0022112077000688](https://pdfs.semanticscholar.org/9344/48b028a3a51a7567c2b441b5ca3e49ebb85c.pdf) (equations 17-19)
# )
#
# This can be rewritten to:
#
# $$
# \nabla \times ( \nabla \times \vec A_{fd} ) = \vec \omega = \nabla \times \vec v.
# $$
# <p style="text-align: right;">(eq. 14)</p>
#
# Or:
#
# $$
# \nabla \times \vec A_{fd}  = \vec v.
# $$
# <p style="text-align: right;">(eq. 15)</p>
#
# We deviate from this definition, by defining the vector potential for the
# acceleration field, rather than the velocity field, and we do this in order to
# maintain consistency with the vector Laplacian throughout the framework, so we
# define the vector potential $\vec A$ by:
#
# $$
# \nabla \times \vec A  = \vec a = \Gamma \nabla \times \nabla \times \vec v.
# $$
# <p style="text-align: right;">(eq. 16)</p>
#
# Or:
#
# $$
# \vec A = \Gamma \nabla \times \vec v = \Gamma \vec \omega,
# $$
# <p style="text-align: right;">(eq. 17)</p>
#
# resulting in a unit of measurement in $[\frac{m^2}{s^2}]$ or velocity squared.
#
# And, in order to avoid confusion, we choose to denote the linear scalar
# potential by $p$ for pressure, the linear force density field by $\vec f$ and
# the angular torque density field by $\vec \tau$, instead.
#
# We can now define the scalar potential by:
#
# $$
# p = \rho \Gamma \nabla \cdot \vec{v} =  \eta \nabla \cdot \vec{v},
# $$
# <p style="text-align: right;">(eq. 18)</p>
#
# resulting in a unit of measurement of **pressure** in $[Pa]$ or $[N/m^2]$ representing **surface force density**.
#
# We can then define the linear **force density** field $\vec{f}$, in $[N/m^3]$ by:
#
# $$
# \vec{f} = - \nabla p = - \eta \nabla  \nabla \cdot \vec{v} .
# $$
# <p style="text-align: right;">(eq. 19)</p>
#
# And from here, we can define the linear acceleration field $\vec{a_l}$ by:
#
# $$
# \vec{a_l} = - \frac{1}{\rho} \nabla p
#           =   \frac{1}{\rho} \vec f
#           = - \Gamma \nabla  \nabla \cdot \vec{v} .
# $$
# <p style="text-align: right;">(eq. 20)</p>
#
#
# And since in fluid dynamics, the vorticity ${\vec \omega}$ is defined as the curl of the velocity field $\vec{v}$:
#
# $$ \vec{\omega} = \nabla \times \vec{v} , $$
# <p style="text-align: right;">(eq. 21)</p>
#
# we can define the angular counterpart of force density $\vec f$, torque density $\vec \tau$, by:
#
# $$
# \vec{\tau} = \eta \vec{\omega}
#            = \eta \nabla \times \vec{v}
#            = \rho \Gamma \nabla \times \vec{v}
#            = \rho \vec A,
# $$
# <p style="text-align: right;">(eq. 22)</p>
#
# which results in a unit of measurement in $[Pa]$ ,$[N/m^2]$, $[\frac{N-m}{m^3}]$
# or $[\frac{kg}{m-s^2}]$ representing **torque density**.
#
# We can subsequently define the angular force density $\vec f_a$, by:
#
# $$
# \vec{f_a} = \rho \vec{a_a}
#           = \nabla \times \vec{\tau}
#           = \eta \nabla \times \omega
#           = \eta \nabla \times \nabla \times \vec{v},
# $$
# <p style="text-align: right;">(eq. 23)</p>
#
# So acceleration $\vec a$ becomes:
#
# $$
# \vec{a} = \vec{a_l} + \vec{a_a}
#         = \frac{1}{\rho} \vec f + \frac{1}{\rho} \vec{f_a}
#         = - \Gamma \nabla  \nabla \cdot \vec{v} + \Gamma \nabla \times \nabla \times \vec{v}
#         = - \Gamma \Delta \vec{v}.
# $$
# <p style="text-align: right;">(eq. 24)</p>
#
# ### Electric and Magnetic Fields
#
# When we consider Coulomb's law:
#
# $$
# \vec F = q \vec E,
# $$
# <p style="text-align: right;">(eq. 25)</p>
#
# we find that $\vec E$ has a unit of measurement in $[\frac{m}{s}]$, which is the unit of measurement for velocity. Therefore, we can define the electric field $\vec E$ by:
#
# $$
# \vec E = \frac{1}{\rho_{q0}} \vec f,
# $$
# <p style="text-align: right;">(eq. 26)</p>
#
# so Coulomb's law becomes:
#
# $$
# \vec F = q \vec E = \frac{q}{\rho_{q0}} \vec f
# $$
# <p style="text-align: right;">(eq. 27)</p>
#
#
# Then, when we consider Ampere's law in it's original form (i.e. without Maxwell's addition of the displacement current):
#
# $$
# \displaystyle \nabla \times \vec{B} = \mu_0 \vec{J},
# $$
# <p style="text-align: right;">(eq. 28)</p>
#
# we can substite $\eta = 1/\mu_0$ to obtain:
#
# $$
# \vec J = \eta \nabla \times \vec B,
# $$
# <p style="text-align: right;">(eq. 29)</p>
#
# However, if we were to substite $\vec B = \vec \tau$, we would obtain a unit of measurement in $[\frac{kg^2}{m^3-s^3}]$ for $\vec J$, resulting in a unit of
# $[\frac{kg^2}{s^3}]$ for the Ampere, which is not equal to $[\frac{C}{s}]$ or $[\frac{kg}{s^2}]$ in our model.
#
# Therefore, we define the (magnetic) field $\vec B$ by:
#
# $$ \vec B = \frac{1}{e} \vec \tau , $$
# <p style="text-align: right;">(eq. 30)</p>
#
# with $e$ elemental charge, resulting in a unit of measurement in $[[\frac{s}{kg}] \times \frac{kg}{m-s^2}] = [\frac{1}{m-s}]$.
#
# And thus we can define the magnetizing field $\vec H$ by:
#
# $$
# \vec H = \eta \vec B = \frac{\eta}{e} \vec \tau,
# $$
# <p style="text-align: right;">(eq. 31)</p>
#
# resulting in a unit of measurement in $[\frac{kg}{m-s}] \times [\frac{1}{m-s}] = [\frac{kg}{m^2-s^2}]$.
#
#
# This way, we can define current density $ \vec{J} $ by:
#
# $$
# \vec{J} = \eta \nabla \times \vec{B} = \nabla \times \vec{H} = \frac{\eta}{e} \nabla \times \vec \tau
# $$
# <p style="text-align: right;">(eq. 32)</p>
#
# resulting in a unit of measurement in $[\frac{kg}{m^3-s^2}]$ for current density $ \vec{J} $, thus resulting in a unit of $[\frac{kg}{s^2}]$ for the Ampere, which is equal to $[\frac{C}{s}]$ or $[\frac{kg}{s^2}]$ in our model.
#
# And thus the Lorentz force becomes:
#
# $$
# \vec{F} = q \left( \frac{1}{\rho_{q0}} \vec{f} + \frac{1}{e} \vec{v} \times \vec{\tau} \right)
# $$
# <p style="text-align: right;">(eq. 33)</p>
#
#
# This way Coulomb's law, Ampere's law and the Lorentz force are integrated in a consistent manner, providing a unified approach where:
#
# - The electric field $\vec{E}$ is defined in terms of the linear force density $\vec{f}$.
# - The magnetic field $\vec{B}$ is defined in terms of the torque density $\vec{\tau}$.
# - The units of measurement align properly with the definitions and physical interpretations within this new framework.

# %% [markdown]
# ### Wave equation and operator
#
# To derive the wave equation in the context of the aether model, we can start by
# considering the time derivative of any given vector field $\vec{F}$ in the
# aether, as we  defined before:
#
# $$ \frac{d \vec F}{dt} = -k \Delta \vec F $$
# <p style="text-align: right;">(eq. 34)</p>
#
# So the second time derivative of any given vector field $\vec F$ becomes:
#
# $$ \frac{d^2 \vec F}{dt^2} = k^2 \Delta^2 \vec F $$
# <p style="text-align: right;">(eq. 35)</p>
#
# We can substitue this in the the d'Alembert or wave operator:
#
# $$
#      \Box ={\frac {1}{c^{2}}}{\partial ^{2} \over \partial t^{2}}-\Delta,
# $$
# <p style="text-align: right;">(eq. 36)</p>
#
# to obtain the second order spatial wave operator:
#
# $$
#      \Box ={\frac {k^2}{c^{2}}}{\Delta^2 }-\Delta.
# $$
# <p style="text-align: right;">(eq. 37)</p>
#
# We can do the same for the wave equation:
#
# $$
# { \left(\Delta -{\frac {1}{c^{2}}}{\frac {\partial ^{2}}{\partial t^{2}}}\right)u(\mathbf {r} ,t)=0.}
# $$
# <p style="text-align: right;">(eq. 38)</p>
#
# To obtain the second order spatial wave equation:
#
# $$
# { \left(\Delta - {\frac {k^2}{c^{2}}}{\Delta^2 }\right)u(\mathbf {r} ,t)=0.}
# $$
# <p style="text-align: right;">(eq. 39)</p>
#
# And by substituting:
#
# $$ \frac{k^2}{c^2} \Delta^2 \vec{v} = \frac{\vec{j}}{c^2} $$
# <p style="text-align: right;">(eq. 40)</p>
#
#
# And:
#
# $$ \Delta \vec{v} = -\frac{\vec{a}}{k} $$
# <p style="text-align: right;">(eq. 41)</p>
#
# This can be simpiified to:
#
# $$ \frac{\vec{j}}{c^2} + \frac{\vec{a}}{k} = 0 $$
# <p style="text-align: right;">(eq. 42)</p>
#
# Using separation of variables in spherical coordinates, this equation can be
# broken down into radial and angular parts, typically involving spherical
# harmonics for the angular component and spherical Bessel functions for the
# radial part. This approach will allow solving the second order spatial wave
# equation for specific boundary conditions and eigenvalues related to the
# physical properties of the aether. The general solution will be a combination of
# these functions:
#
# $$ \vec{F}(r, \theta, \phi) = \sum_{l=0}^{\infty} \sum_{m=-l}^{l} \left[ A_{lm} j_l(kr) + B_{lm} y_l(kr) \right] Y_{lm}(\theta, \phi) $$
# <p style="text-align: right;">(eq. 43)</p>
#
# Where:
#
# - $ j_l(kr) $ are the spherical Bessel functions.
# - $ y_l(kr) $ are the spherical Neumann functions.
# - $ Y_{lm}(\theta, \phi) $ are the spherical harmonics.
# - $ A_{lm} $ and $ B_{lm} $ are coefficients determined by boundary conditions.
#
# These solutions are consistent with those found in quantum mechanics, but
# without the need for probabilistic interpretations. And given that these
# solutions are valid at both large and small scales, these are sufficient to
# explain what we now call nuclear forces, so the hypothesis of the existence of
# distinct nuclear forces (strong and weak) is no longer necessary.

# %% [markdown]
# ## The Gravitational Force
#
# Now that we have integrated the electromagnetic fields into the model, we can
# also consider the gravitational force. And since there is only one aether, there
# can be only one fundamental force of nature. And therefore, the gravitational
# force must be a result of the fundamental forces carried by the aether and is
# probably a combination of two mechanisms. The first is "pushing" or "shadow"
# gravity after Le Sage's theory of gravitation (large, galactic scale). The
# second is the Biefeld-Brown effect (planetary scale).
#
# With respect to "shadow" gravity, we refer to the work of Paul Stowe, who has
# a/o shown that with such a model it is possible to describe rotation profiles of
# spiral galaxies in accordance with observations.
#
# (Ref: [Spiral Galaxy Rotation Profiles in Shadow Gravity](https://vixra.org/abs/2112.0128) )
#
# (Ref: [Deriving Newton's Gravitational Law from a Le Sage Mechanism](http://www.tuks.nl/pdf/Reference_Material/Paul_Stowe/Stowe_in_PushingGravity.pdf) )
#
# With respect to the Biefeld-Brown effect, we find an excellent explanation of this effect
# by none other than Richard Feynman:
#
# (Ref: [The Feynman Lectures on Physics Vol. II Ch. 10: Dielectrics](https://www.feynmanlectures.caltech.edu/II_10.html#Ch10-F8) )
#
#
# "*As illustrated in Fig. 10–8, a dielectric is always drawn from a region of
# weak field toward a region of stronger field. In fact, **one can prove that for
# small objects the force is proportional to the gradient of the square of the
# electric field**. Why does it depend on the square of the field? Because the
# induced polarization charges are proportional to the fields, and for given
# charges the forces are proportional to the field. However, as we have just
# indicated, there will be a net force only if the square of the field is changing
# from point to point. So the force is proportional to the gradient of the square
# of the field. The constant of proportionality involves, among other things, the
# dielectric constant of the object, and it also depends upon the size and shape
# of the object.*"
#
# So, if it can be proven that a force proportional to the electric field squared
# exists, as Feynman claims, it would seem that the most simple explanation is
# that this force represents (anti)gravity and thus we can define the
# gravitational force density field $\vec{f_g}$ by:
#
# $$
# \vec{f_g} = -\rho \nabla (\vec{E} \cdot \vec{E})
# $$
# <p style="text-align: right;">(eq. 44)</p>
#
# While the graviational force acting on an object with mass $m$ becomes:
#
# $$
# \vec{F} = - m \nabla (\vec{E} \cdot \vec{E})
# $$
# <p style="text-align: right;">(eq. 45)</p>
#
# Dimensionally, this works out quite nicely, since in our model the electric field has a
# unit of measurement in $[\frac{m}{s}]$, so the the electric field squared has a
# unit of measurement in $[\frac{m^2}{s^2}]$ and thus the gradient thereof yields
# an acceleration in $[\frac{m}{s^2}]$.
#
# This way, we have come to a unification of the gravitational and electromagnetic
# forces within one superfluid second order aether model.

# %% [markdown]
# ## Conclusion: A Unified Theory of Everything
#
# The logic of the superfluid aether model demands that if there is only one aether, there can be only one fundamental force of Nature. Both nuclear and gravitational forces can be understood as different manifestations of this single force, described by Newton's third in three dimensions in terms of densities per cubic meter:
#
# $$
# \vec{f} = \rho \vec a = -\rho k \Delta \vec v = - \eta \Delta \vec v
# $$
# <p style="text-align: right;">(eq. 46)</p>
#
# However, besides a fundamental force, we have also found a fundamental yank,
# the time derivative of force density, which is given by:
#
# $$
# \vec{y} = \rho \vec j = -\rho k \Delta \vec a = - \eta \Delta \vec a
# $$
# <p style="text-align: right;">(eq. 47)</p>
#
# It is these two fields that describe the dynamics of the superfluid aether,
# together with the second order spatial wave equation.
#
# Finally, David LaPoint’s Primer Fields experiments have demonstrated how
# magnetic fields can produce self-organizing behavior, from small to large
# scales. These observations provide empirical support for the idea that
# electromagnetic forces, mediated by the aether, are sufficient to explain both
# nuclear and gravitational phenomena.
#
# The self-organizing behaviors observed in LaPoint’s experiments suggest that
# forces we typically attribute to nuclear and gravitational interactions can
# emerge from electromagnetic fields structured by the aether. This aligns with
# the predictions of the superfluid aether model and supports the conclusion that
# there is only one fundamental force of nature.
#
# (Ref: [The Primer Fields Part 1 International Ver.](https://youtu.be/siMFfNhn6dk?si=6aHiYk9WVk-Ed-uz&t=1181) )
#
#
# And thus we come to the conclusion that our new theory represents a significant
# simplification of the current understanding of fundamental forces, eliminating
# the need for distinct nuclear and gravitational forces while providing a
# coherent and **fundamental second order framework** for understanding
# interactions at all scales without the need for probabilistic interpretations
# while adhering to the **fundamental principles of vector calculus** in contrast
# to the current fluid dynamic (based) theories: Maxwell and Navier-Stokes.
#
# <p style="text-align: center;">Q.E.D</p>
